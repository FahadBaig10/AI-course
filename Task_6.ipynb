# %% [markdown]
# # <font color='red'>1. Rename the Notebook with your name and roll number</font>
# # <font color='red'>2. Write your Name and Roll number in the cell below</font>

# %% [markdown]
# # Name: Fahad Baig
# # Roll Number: 19I1883

# %% [markdown]
# # Task-1
# ### Plot the Male Vs Female Births over the years from the "births.csv" dataset given

# %%
# Solution Looks Like this after I plotted your trand should look the same.

# %%
# Start Coding Here


import numpy as np
import pandas as pd
import seaborn as sns
births = pd.read_csv('births.csv')

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
sns.set()
births.pivot_table('births', index='year', columns='gender', aggfunc='sum').plot()
plt.ylabel('total births per year');

# %% [markdown]
# # Task-2
# ### Plot Average daily births by day of week and decade

# %%
# Solution Looks like this don't run this cell

# %%
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
births = pd.read_csv('births.csv')
births.head()
# Out:
#    year  month  day gender  births
# 0  1969      1  1.0      F    4046
# 1  1969      1  1.0      M    4440
# 2  1969      1  2.0      F    4454
# 3  1969      1  2.0      M    4548
# 4  1969      1  3.0      F    4548

# %% [markdown]
# ### As you can see above,
# ### You don't have datetime calculated as index which is used to calculate day of the week
# ### You don't have the decades value and which day of the week this is.
# ### Let me calculate these for you

# %%
births['decade'] = 10 * (births['year'] // 10)
quartiles = np.percentile(births['births'], [25, 50, 75])
mu = quartiles[1]
sig = 0.74 * (quartiles[2] - quartiles[0])
births = births.query('(births > @mu - 5 * @sig) & (births < @mu + 5 * @sig)')
births.index = pd.to_datetime(10000 * births.year + 100 * births.month + births.day, format='%Y%m%d')
births['dayofweek'] = births.index.dayofweek

# %% [markdown]
# ### Now you've got:

# %%
births.head()
# Out:
#             year  month  day gender  births  decade  dayofweek
# 1969-01-01  1969      1  1.0      F    4046    1960          2
# 1969-01-01  1969      1  1.0      M    4440    1960          2
# 1969-01-02  1969      1  2.0      F    4454    1960          3
# 1969-01-02  1969      1  2.0      M    4548    1960          3
# 1969-01-03  1969      1  3.0      F    4548    1960          4

# %%
# First Generate the pivot table like the one given below

# %%
# Plot the average births each day of the week in every decade
# For example gow many births each day of the week in 1960's and so on

# %% [markdown]
# ## Hints:
# ### Use pivot table to plot the births with index and columns being days of week and decades respectively
# ### Use mean as the ```aggfunc```
# ### Set xlabels to be ```sat```,```sun```,```mon``` instead of ```1```,```2```,```3``` but do this later after you are done with everything

# %% [markdown]
# ### Starter Code:

# %%
import matplotlib.pyplot as plt 
import matplotlib as mpl

# %%
# Start Coding here

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
sns.set()
births.pivot_table('births' , index='dayofweek', columns='decade' , aggfunc='mean').plot()
plt.gca().set_xticklabels(['Mon', 'Tues', 'Wed', 'Thurs', 'Fri', 'Sat', 'Sun'])
plt.ylabel('mean births by day');
